# %% [markdown]
# #logistic regression

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.read_csv(r"C:\Users\mayur\machine learning\Churn.csv")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
cr=pd.read_csv(r"C:\Users\mayur\machine learning\Churn.csv")

# %%
cr.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
from sklearn. preprocessing import LabelEncoder
le=LabelEncoder()

# %%
cr.gender=le.fit_transform(cr.gender)
cr.Partner=le.fit_transform(cr.Partner)
cr.Dependents=le.fit_transform(cr.Dependents)
cr.PhoneService=le.fit_transform(cr.PhoneService)
cr.MultipleLines=le.fit_transform(cr.MultipleLines)
cr.InternetService=le.fit_transform(cr.InternetService)
cr.OnlineSecurity=le.fit_transform(cr.OnlineSecurity)
cr.OnlineBackup=le.fit_transform(cr.OnlineBackup)
cr.DeviceProtection=le.fit_transform(cr.DeviceProtection)
cr.TechSupport=le.fit_transform(cr.TechSupport)
cr.StreamingTV=le.fit_transform(cr.StreamingTV)
cr.StreamingMovies=le.fit_transform(cr.StreamingMovies)
cr.Contract=le.fit_transform(cr.Contract)
cr.PaperlessBilling=le.fit_transform(cr.PaperlessBilling)
cr.PaymentMethod=le.fit_transform(cr.PaymentMethod)
cr.TotalCharges=le.fit_transform(cr.TotalCharges)
cr.customerID=le.fit_transform(cr.customerID)
cr.Churn=le.fit_transform(cr.Churn)

# %%
cr.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0        5375       0              0        1           0       1
# 1        3962       1              0        0           0      34
# 2        2564       1              0        0           0       2
# 3        5535       1              0        0           0      45
# 4        6511       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
cr[cr.select_dtypes(include='object').columns] =cr[cr.select_dtypes(include='object').columns].apply(le.fit_transform)

# %%
from sklearn.model_selection import train_test_split
cr_train,cr_test=train_test_split(cr,test_size=.2)

# %%
cr_train_x=cr_train.iloc[:,0:-1]
cr_train_y=cr_train.iloc[:,-1]

cr_test_x=cr_test.iloc[:,0:-1]
cr_test_y=cr_test.iloc[o:,-1]

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg=LogisticRegression()
logreg.fit(cr_train_x,cr_train_y)
# Out:
# LogisticRegression()

# %%
pred_train=logreg.predict(cr_train_x)
pred_test=logreg.predict(cr_test_x)

# %%
from sklearn.metrics import confusion_matrix
mat_test=confusion_matrix(cr_test_y,pred_test)

# %%
mat_test
# Out:
# array([[906, 123],
#        [161, 219]])

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
145/(145+913)*100
# Out:
# 13.705103969754253

# %%
accuracy_score(cr_test_y,pred_test)
# Out:
# 0.7984386089425124

# %%
206-145
# Out:
# 61

# %%
recall_score(cr_test_y,pred_test)
# Out:
# 0.5763157894736842

# %%
precision_score(cr_test_y,pred_test)
# Out:
# 0.6403508771929824

# %%
f1_score(cr_test_y,pred_test)
# Out:
# 0.6066481994459834

# %%
pred_prob_test=logreg.predict_proba(cr_test_x)
len(pred_prob_test)
# Out:
# 1409

# %%
from sklearn.metrics import roc_auc_score,roc_curve

# %%
roc_auc_score(cr_test_y,pred_prob_test[:,1])
# Out:
# np.float64(0.845938826658483)

# %%
fpr,tpr,thre=roc_curve(cr_test_y,pred_prob_test[:,1])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(fpr,tpr,marker='*',color='green')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('roc plot on fpr and tpr')
plt.grid()

# %% [markdown]
# DATASETS

# %%
# attrition 
# diabetes 
#surgical_deepnet

# %%
pd.read_csv(r"C:\Users\mayur\machine learning\diabetesLogistic.csv")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dia=pd.read_csv(r"C:\Users\mayur\machine learning\diabetesLogistic.csv")

# %%
dia.isnull().sum()[dia.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
dia.select_dtypes(include='object').columns
# Out:
# Index([], dtype='object')

# %%
dia.isnull().sum()[dia.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
dia.select_dtypes(include='object').columns
# Out:
# Index([], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dia.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
